# %%
#Basketball Client Retention and Revenue Analytics Data Science Project
#Roman Espindola
#Syracuse University '27
#Applied Data Science

# %%
import sys
print(sys.executable)
# Out:
# /Users/romanespindola/Downloads/Basketball Client Retention & Revenue Analytics/.venv/bin/python

# %%
#importing necessary packages 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

from sklearn.model_selection import GroupKFold, cross_validate 
#used to split data for training/testing
from sklearn.compose import ColumnTransformer 
#applies preprocessing to different columns
from sklearn.preprocessing import OneHotEncoder, StandardScaler 
#OneHot converts categorical columns into binary columns
#Standard Scalar scales numeric column
from sklearn.pipeline import Pipeline
#Chains steps into one model object
from sklearn.impute import SimpleImputer
#fills in missing values
#numeric: auto fills with median
#categorical: auto fills with mode
from sklearn.metrics import classification_report, confusion_matrix
#Classification_report prints precision, recall, f1-score for each class
from sklearn.linear_model import LogisticRegression
#Helps me create baselines regression models
from sklearn.ensemble import RandomForestClassifier
#Captures non-linear relationships plus interactions

from joblib import dump, load
#Saves/loads trained models to disk
#dump = saves model
#load = loads model

print("✅ Imports successful")
# Out:
# ✅ Imports successful
